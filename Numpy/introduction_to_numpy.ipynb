# %%
import numpy as np

# %% [markdown]
# ## Problem Statement 1
# ### Adding 5 to each element of the array using numpy

# %%
lst = [5, 10 , 15, 20, 25]

arr = np.array(lst)
arr += 5

print(arr)
# Out:
# [10 15 20 25 30]

# %% [markdown]
# ## Problem Statement 2
# ### Given a list lst do a homogeneity test on each element.

# %%
# Input
lst = [1, 2, 3, 'text', True, 3+2j]

arr = np.array(lst)
print(type(arr[0]), type(arr[-1]))
# Out:
# <class 'numpy.str_'> <class 'numpy.str_'>

# %% [markdown]
# ## Problem Statement 3
# ### Get Size of Array in Bites

# %%
lst = [56, 45, 12, 6]

arr = np.array(lst)
print(arr.nbytes)
# Out:
# 32
