# %% [markdown]
# ### Integrated Plots

# %% [markdown]
# So far, we have used all the starting seven features to illustrate comparison among the traits of all three Pokemon. Next, we take the last two features namely Weight and Height and plot a bar graph as shown:

# %%
           
# continuing from previous code
ax5 = plt.subplot2grid((4,3), (1,1), colspan=2, rowspan = 3)
bar_width = 0.2
wdt = 0
names = ['Bulbasaur','Charmander','Squirtle']
for i in range(0, 3):
    p=ax5.barh(np.arange(2) + wdt, hw[i],bar_width,
             alpha = 0.5,
             color = colors[i],
             label = names[i])
    wdt += bar_width
ax5.legend(loc = 'lower right')
ax5.set_xlim(0,12)
ax5.set_ylim(-0.2,1.8)
plt.yticks(np.arange(2) + (bar_width)*1.5, 
           ('Height', 'Weight'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # continuing from previous code
# ----> 2 ax5 = plt.subplot2grid((4,3), (1,1), colspan=2, rowspan = 3)
#       3 bar_width = 0.2
#       4 wdt = 0
#       5 names = ['Bulbasaur','Charmander','Squirtle']
#
# NameError: name 'plt' is not defined

# %% [markdown]
# This results in a complete figure which constitutes 5 different subplots. However, try minimizing the graph to a smaller scale and you will start noticing the overlapping of graphs and labels. To prevent this problem Matplotlib provides a niche function called tight_layout(). Let us add this function in our module.

# %%
           
plt.tight_layout()

# %% [markdown]
# We can also manipulate the background style of the figure using style.use('name') command. There are many inbuilt styles available which can be found using style.available() command. We use seaborn-dark theme to add final touch on the figure.

# %%
           
plt.style.use('seaborn-dark')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.style.use('seaborn-dark')
#       2
#
# NameError: name 'plt' is not defined
