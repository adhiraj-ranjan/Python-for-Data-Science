# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Given the values for variables x and y. Arrive at the following plot as shown below.

# %% [markdown]
# ```
#
#
# import numpy as np
# x = np.array([1,1,1,1,2,3,4,4,4,4,3,2,1])
# y = np.array([1,2,3,4,4,4,4,3,2,1,1,1,1])
#
#
#
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,1,1,1,2,3,4,4,4,3,2,1,1])
y = np.array([1,2,3,4,4,4,4,4,3,2,1,1,1])

# %%
plt.plot(x, y)

plt.text(4, 2.5, "Text2", rotation=90)
plt.text(1, 3.8, "Text3\nnext line", rotation=45)

plt.show()
