# %% [markdown]
# ### Introduction to Scikit-learn

# %% [markdown]
# Scikit-Learn (sklearn) is a devoted machine learning platform introduced in Python. It provides simple and efficient tools for data mining and data analysis. It has been built upon Numpy, Scipy and Matplotlib modules which we have learnt so far. Moreover, sklearn is open source and commercially usable under BSD license.
#
# Common prevalent techniques are pre-processing, classification, regression, clustering, dimensionality reduction, model selection etc. In our course, we will focus on the implementation of the following topics:

# %% [markdown]
# Linear regression
#
# Logistic regression
#
# Decision trees
#
# Clustering
